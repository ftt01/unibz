# %%
import sys

lib_dir = "/home/daniele/documents/github/ftt01/phd/share/lib"
sys.path.insert( 0, lib_dir )

# %%
from lib import *

# %%
wdir = "/home/daniele/documents/github/ftt01/phd/projects/era5_evaluation/"
current = DataCollector(configPath=wdir + "etc/conf/")

# %%
## SETUP
basin = 'AA'
# for output name
basin_str = 'alto_adige'

start_date_str = "2010-01-01T00:00:00"
end_date_str = "2019-12-31T23:00:00"
start_date = dt.datetime.strptime( start_date_str, '%Y-%m-%dT%H:%M:%S' )
end_date = dt.datetime.strptime( end_date_str, '%Y-%m-%dT%H:%M:%S' )

# %%
## GROUND STATIONS DATASET ##
# metadata
gs_metadata = "/media/windows/projects/era5_bias/00_data/meteo/aa/AA_stations_metadata.csv"
metadata_tot = pd.read_csv( gs_metadata, header=0 )

# %%
a=0
b=1000
c=1800

# %%
fascia_a = metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagP"]==1][metadata_tot["Elevation"]>=a][metadata_tot["Elevation"]<b]
fascia_b = metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagP"]==1][metadata_tot["Elevation"]>=b][metadata_tot["Elevation"]<c]
fascia_c = metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagP"]==1][metadata_tot["Elevation"]>=c]
# Out:
# /tmp/ipykernel_2521533/1484607150.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fascia_a = metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagP"]==1][metadata_tot["Elevation"]>=a][metadata_tot["Elevation"]<b]
# /tmp/ipykernel_2521533/1484607150.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fascia_b = metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagP"]==1][metadata_tot["Elevation"]>=b][metadata_tot["Elevation"]<c]
# /tmp/ipykernel_2521533/1484607150.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fascia_c = metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagP"]==1][metadata_tot["Elevation"]>=c]

# %%
input_dir = "/media/windows/projects/era5_bias/kriging/new_version/output/alberto/precipitation/CV/OKED/DEUTSCH/stats/"
all_P = glob.glob(input_dir+"*.txt")

print("PRECIPITATION")

a_rmses = []
a_count = 0
for a_idx in fascia_a.index:
    c_id = fascia_a.loc[a_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_RMSE = c_df.loc["hourly"]["RMSE"]
                # print(c_RMSE)
                a_rmses.append(c_RMSE)
                a_count = a_count +1
    except:
        # print(c_id)
        continue

a_rmses_mean = np.mean(a_rmses)
print(f"RMSE fascia tra {a} e {b} on {a_count}: {a_rmses_mean}")

b_rmses = []
b_count = 0
for b_idx in fascia_b.index:
    c_id = fascia_b.loc[b_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_RMSE = c_df.loc["hourly"]["RMSE"]
                # print(c_RMSE)
                b_rmses.append(c_RMSE)
                b_count = b_count +1
    except:
        # print(c_id)
        continue

b_rmses_mean = np.mean(b_rmses)
print(f"RMSE fascia tra {b} e {c} on {b_count}: {b_rmses_mean}")

c_rmses = []
c_count = 0
for c_idx in fascia_c.index:
    c_id = fascia_c.loc[c_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_RMSE = c_df.loc["hourly"]["RMSE"]
                # print(c_RMSE)
                c_rmses.append(c_RMSE)
                c_count = c_count +1
    except:
        # print(c_id)
        continue

c_rmses_mean = np.mean(c_rmses)
print(f"RMSE fascia oltre {c} on {c_count}: {c_rmses_mean}")

############################################################

input_dir = "/media/windows/projects/era5_bias/kriging/new_version/output/alberto/temperature/CV/OKED/DEUTSCH/stats/"
all_P = glob.glob(input_dir+"*.txt")

print("TEMPERATURE")

a_rmses = []
a_count = 0
for a_idx in fascia_a.index:
    c_id = fascia_a.loc[a_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_RMSE = c_df.loc["hourly"]["RMSE"]
                # print(c_RMSE)
                a_rmses.append(c_RMSE)
                a_count = a_count +1
    except:
        # print(c_id)
        continue

a_rmses_mean = np.mean(a_rmses)
print(f"RMSE fascia tra {a} e {b} on {a_count}: {a_rmses_mean}")

b_rmses = []
b_count = 0
for b_idx in fascia_b.index:
    c_id = fascia_b.loc[b_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_RMSE = c_df.loc["hourly"]["RMSE"]
                # print(c_RMSE)
                b_rmses.append(c_RMSE)
                b_count = b_count +1
    except:
        # print(c_id)
        continue

b_rmses_mean = np.mean(b_rmses)
print(f"RMSE fascia tra {b} e {c} on {b_count}: {b_rmses_mean}")

c_rmses = []
c_count = 0
for c_idx in fascia_c.index:
    c_id = fascia_c.loc[c_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_RMSE = c_df.loc["hourly"]["RMSE"]
                # print(c_RMSE)
                c_rmses.append(c_RMSE)
                c_count = c_count +1
    except:
        # print(c_id)
        continue

c_rmses_mean = np.mean(c_rmses)
print(f"RMSE fascia oltre {c} on {c_count}: {c_rmses_mean}")
# Out:
# PRECIPITATION
# RMSE fascia tra 0 e 1000 on 43: 0.3922258567323386
# RMSE fascia tra 1000 e 1800 on 55: 0.3820516322420694
# RMSE fascia oltre 1800 on 16: 0.3987849756158024
# TEMPERATURE
# RMSE fascia tra 0 e 1000 on 43: 2.05554212575554
# RMSE fascia tra 1000 e 1800 on 56: 1.6936556396323807
# RMSE fascia oltre 1800 on 16: 1.8541044158795472

# %%
input_dir = "/media/windows/projects/era5_bias/kriging/new_version/output/alberto/precipitation/CV/OKED/DEUTSCH/stats/"
all_P = glob.glob(input_dir+"*.txt")

print("PRECIPITATION")

a_maes = []
a_count = 0
for a_idx in fascia_a.index:
    c_id = fascia_a.loc[a_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_MAE = c_df.loc["hourly"]["MAE"]
                # print(c_MAE)
                a_maes.append(c_MAE)
                a_count = a_count +1
    except:
        # print(c_id)
        continue

a_maes_mean = np.mean(a_maes)
print(f"MAE fascia tra {a} e {b} on {a_count}: {a_maes_mean}")

b_maes = []
b_count = 0
for b_idx in fascia_b.index:
    c_id = fascia_b.loc[b_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_MAE = c_df.loc["hourly"]["MAE"]
                # print(c_MAE)
                b_maes.append(c_MAE)
                b_count = b_count +1
    except:
        # print(c_id)
        continue

b_maes_mean = np.mean(b_maes)
print(f"MAE fascia tra {b} e {c} on {b_count}: {b_maes_mean}")

c_maes = []
c_count = 0
for c_idx in fascia_c.index:
    c_id = fascia_c.loc[c_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_MAE = c_df.loc["hourly"]["MAE"]
                # print(c_MAE)
                c_maes.append(c_MAE)
                c_count = c_count +1
    except:
        # print(c_id)
        continue

c_maes_mean = np.mean(c_maes)
print(f"MAE fascia oltre {c} on {c_count}: {c_maes_mean}")

############################################################

input_dir = "/media/windows/projects/era5_bias/kriging/new_version/output/alberto/temperature/CV/OKED/DEUTSCH/stats/"
all_P = glob.glob(input_dir+"*.txt")

print("TEMPERATURE")

a_maes = []
a_count = 0
for a_idx in fascia_a.index:
    c_id = fascia_a.loc[a_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_MAE = c_df.loc["hourly"]["MAE"]
                # print(c_MAE)
                a_maes.append(c_MAE)
                a_count = a_count +1
    except:
        # print(c_id)
        continue

a_maes_mean = np.mean(a_maes)
print(f"MAE fascia tra {a} e {b} on {a_count}: {a_maes_mean}")

b_maes = []
b_count = 0
for b_idx in fascia_b.index:
    c_id = fascia_b.loc[b_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_MAE = c_df.loc["hourly"]["MAE"]
                # print(c_MAE)
                b_maes.append(c_MAE)
                b_count = b_count +1
    except:
        # print(c_id)
        continue

b_maes_mean = np.mean(b_maes)
print(f"MAE fascia tra {b} e {c} on {b_count}: {b_maes_mean}")

c_maes = []
c_count = 0
for c_idx in fascia_c.index:
    c_id = fascia_c.loc[c_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_MAE = c_df.loc["hourly"]["MAE"]
                # print(c_MAE)
                c_maes.append(c_MAE)
                c_count = c_count +1
    except:
        # print(c_id)
        continue

c_maes_mean = np.mean(c_maes)
print(f"MAE fascia oltre {c} on {c_count}: {c_maes_mean}")
# Out:
# PRECIPITATION
# MAE fascia tra 0 e 1000 on 43: 0.05837573082061963
# MAE fascia tra 1000 e 1800 on 55: 0.07233759554082791
# MAE fascia oltre 1800 on 16: 0.08804028486613699
# TEMPERATURE
# MAE fascia tra 0 e 1000 on 43: 1.6924083313290794
# MAE fascia tra 1000 e 1800 on 56: 1.2992226431396638
# MAE fascia oltre 1800 on 16: 1.4373763105346884

# %%
input_dir = "/media/windows/projects/era5_bias/kriging/new_version/output/alberto/precipitation/CV/OKED/DEUTSCH/stats/"
all_P = glob.glob(input_dir+"*.txt")

print("PRECIPITATION")

a_biass = []
a_count = 0
for a_idx in fascia_a.index:
    c_id = fascia_a.loc[a_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_BIAS = c_df.loc["hourly"]["BIAS"]
                # print(c_BIAS)
                a_biass.append(c_BIAS)
                a_count = a_count +1
    except:
        # print(c_id)
        continue

a_biass_mean = np.mean(a_biass)
print(f"BIAS fascia tra {a} e {b} on {a_count}: {a_biass_mean}")

b_biass = []
b_count = 0
for b_idx in fascia_b.index:
    c_id = fascia_b.loc[b_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_BIAS = c_df.loc["hourly"]["BIAS"]
                # print(c_BIAS)
                b_biass.append(c_BIAS)
                b_count = b_count +1
    except:
        # print(c_id)
        continue

b_biass_mean = np.mean(b_biass)
print(f"BIAS fascia tra {b} e {c} on {b_count}: {b_biass_mean}")

c_biass = []
c_count = 0
for c_idx in fascia_c.index:
    c_id = fascia_c.loc[c_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_BIAS = c_df.loc["hourly"]["BIAS"]
                # print(c_BIAS)
                c_biass.append(c_BIAS)
                c_count = c_count +1
    except:
        # print(c_id)
        continue

c_biass_mean = np.mean(c_biass)
print(f"BIAS fascia oltre {c} on {c_count}: {c_biass_mean}")

############################################################

input_dir = "/media/windows/projects/era5_bias/kriging/new_version/output/alberto/temperature/CV/OKED/DEUTSCH/stats/"
all_P = glob.glob(input_dir+"*.txt")

print("TEMPERATURE")

a_biass = []
a_count = 0
for a_idx in fascia_a.index:
    c_id = fascia_a.loc[a_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_BIAS = c_df.loc["hourly"]["BIAS"]
                # print(c_BIAS)
                a_biass.append(c_BIAS)
                a_count = a_count +1
    except:
        # print(c_id)
        continue

a_biass_mean = np.mean(a_biass)
print(f"BIAS fascia tra {a} e {b} on {a_count}: {a_biass_mean}")

b_biass = []
b_count = 0
for b_idx in fascia_b.index:
    c_id = fascia_b.loc[b_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_BIAS = c_df.loc["hourly"]["BIAS"]
                # print(c_BIAS)
                b_biass.append(c_BIAS)
                b_count = b_count +1
    except:
        # print(c_id)
        continue

b_biass_mean = np.mean(b_biass)
print(f"BIAS fascia tra {b} e {c} on {b_count}: {b_biass_mean}")

c_biass = []
c_count = 0
for c_idx in fascia_c.index:
    c_id = fascia_c.loc[c_idx]["ID"]
    # print(c_id)
    
    try:
        for f in all_P:
            if (f"_{c_id}_" in f):
                c_file = f
                # print(c_file)
                c_df = pd.read_csv(c_file, index_col=0)
                # print(c_df)
                c_BIAS = c_df.loc["hourly"]["BIAS"]
                # print(c_BIAS)
                c_biass.append(c_BIAS)
                c_count = c_count +1
    except:
        # print(c_id)
        continue

c_biass_mean = np.mean(c_biass)
print(f"BIAS fascia oltre {c} on {c_count}: {c_biass_mean}")
# Out:
# PRECIPITATION
# BIAS fascia tra 0 e 1000 on 43: -0.005396488602669172
# BIAS fascia tra 1000 e 1800 on 55: 0.0024423736470830615
# BIAS fascia oltre 1800 on 16: 0.004888491859716481
# TEMPERATURE
# BIAS fascia tra 0 e 1000 on 43: 1.2100434297041123
# BIAS fascia tra 1000 e 1800 on 56: 0.24576615284718198
# BIAS fascia oltre 1800 on 16: -0.005718487193137861

# %%
# metadata_tot.sort_values("Elevation", ascending=False)[metadata_tot["flagT"]==1][0:10]

# %%
# metadata_tot

# %%
# precipitation_gs = metadata_tot[metadata_tot['flagP']==1][['ID','Elevation']].set_index('ID').rename(columns={'Elevation':'precipitation'})
# temperature_gs = metadata_tot[metadata_tot['flagT']==1][['ID','Elevation']].set_index('ID').rename(columns={'Elevation':'temperature'})

# %%
# precipitation_gs

# %%
# xx = pd.concat( [precipitation_gs, temperature_gs], axis=1 )

# plt.hist([xx['precipitation'], xx['temperature']], 25, label=['precipitation', 'temperature'])
# plt.legend(loc='upper right')
# # plt.show()

# %%
# output_path = current.config["output_path"] + "meteo/alto_adige/"
# mkNestedDir(output_path)

# ##
# output_file = output_path + "gs_histograph_vsElevation.tiff"

# c_fig, c_axs = instantiatePlot( 'Elevation [m]', 'N. of stations' )
# c_axs.hist([xx['precipitation'], xx['temperature']], bins=25, color=['y','g'], label=['precipitation','temperature'])
# c_axs.set_ylim(0,20)
# c_axs.legend()
# plt.xticks(np.arange(0,3500,250))
# plt.yticks(np.arange(0,20,2))
# plt.tight_layout()
# c_fig.savefig(
#     output_file, 
#     format='tiff',
#     facecolor='w',
#     dpi=300)

# plt.close(fig=c_fig)

# ##

# output_file_hd = output_path + "gs_histograph_vsElevation_HD.tiff"

# c_fig, c_axs = instantiatePlot( 'Elevation [m]', 'N. of stations' )
# c_axs.hist([xx['precipitation'], xx['temperature']], bins=25, color=['y','g'], label=['precipitation','temperature'])
# c_axs.set_ylim(0,20)
# c_axs.legend()
# plt.xticks(np.arange(0,3500,250))
# plt.yticks(np.arange(0,20,2))
# plt.tight_layout()
# c_fig.savefig(
#     output_file_hd, 
#     format='tiff',
#     facecolor='w',
#     dpi=600)

# plt.close(fig=c_fig)
